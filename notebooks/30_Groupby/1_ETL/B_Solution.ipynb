# %% [markdown]
# # ETL: Extract, Transform, Load

# %% [markdown]
# Download a dataset from [Kaggle](https://kaggle.com/) to develop this project.
#
# **Note**: It must contain at least:
#
# - 50 rows
# - 2 categorical columns
# - 2 numerical columns

# %% [markdown]
# ## Load data

# %%
import pandas as pd

df_base = pd.read_csv('../data/p48_2015_2022_EN.csv')
df_base
# Out:
#                     datetime_utc  Hydraulic  Adjustment P48  Balance Andorra  \
# 0      2015-01-01 00:00:00+01:00    2621.90          1300.0            -36.0
# 1      2015-01-01 01:00:00+01:00    2532.30          1000.0            -35.0
# ...                          ...        ...             ...              ...
# 70126  2022-12-31 22:00:00+01:00    4055.50          -200.0            -67.0
# 70127  2022-12-31 23:00:00+01:00    3963.95          -200.0            -62.0
#
#        Balance Morocco  Balance France  Balance Portugal  Other Renewables  \
# 0               -540.0         -1000.0             291.7             486.4
# 1               -600.0         -1100.0             -44.1             486.4
# ...                ...             ...               ...               ...
# 70126           -740.0         -1715.8            3355.0             259.2
# 70127           -750.0          -258.0            2755.0             257.2
#
#        Non-Renewable Waste  Cogeneration      Wind  Fuel-Gas    Coal  \
# 0                      NaN        1586.9  5517.400     421.6  5077.9
# 1                      NaN        1591.2  5034.400     422.3  5086.3
# ...                    ...           ...       ...       ...     ...
# 70126                264.7         760.6  8871.225       NaN   260.0
# 70127                264.9         761.6  7506.300       NaN   260.0
#
#        Balearic Link  Pumping Consumption  Solar Thermal  Solar Photovoltaic  \
# 0             -128.0             -850.000           16.0                 NaN
# 1             -102.0             -850.000           16.0                 NaN
# ...              ...                  ...            ...                 ...
# 70126         -153.0            -1846.700            NaN                 1.7
# 70127         -128.0            -2632.025            NaN                 1.6
#
#        Combined Cycle  Pumping Turbine  Nuclear
# 0             3458.10              NaN  7105.00
# 1             3789.50              NaN  7104.00
# ...               ...              ...      ...
# 70126         1725.00         689.6000  6457.75
# 70127         2104.55         240.9125  6415.45
#
# [70128 rows x 20 columns]

# %% [markdown]
# ## Clean and preprocess data

# %%
df_base['datetime_utc'] = pd.to_datetime(df_base['datetime_utc'], utc=True)
df_base = df_base.set_index('datetime_utc')
df_base = df_base.tz_convert('Europe/Madrid')
df_base
# Out:
#                            Hydraulic  Adjustment P48  Balance Andorra  \
# datetime_utc
# 2015-01-01 00:00:00+01:00    2621.90          1300.0            -36.0
# 2015-01-01 01:00:00+01:00    2532.30          1000.0            -35.0
# ...                              ...             ...              ...
# 2022-12-31 22:00:00+01:00    4055.50          -200.0            -67.0
# 2022-12-31 23:00:00+01:00    3963.95          -200.0            -62.0
#
#                            Balance Morocco  Balance France  Balance Portugal  \
# datetime_utc
# 2015-01-01 00:00:00+01:00           -540.0         -1000.0             291.7
# 2015-01-01 01:00:00+01:00           -600.0         -1100.0             -44.1
# ...                                    ...             ...               ...
# 2022-12-31 22:00:00+01:00           -740.0         -1715.8            3355.0
# 2022-12-31 23:00:00+01:00           -750.0          -258.0            2755.0
#
#                            Other Renewables  Non-Renewable Waste  \
# datetime_utc
# 2015-01-01 00:00:00+01:00             486.4                  NaN
# 2015-01-01 01:00:00+01:00             486.4                  NaN
# ...                                     ...                  ...
# 2022-12-31 22:00:00+01:00             259.2                264.7
# 2022-12-31 23:00:00+01:00             257.2                264.9
#
#                            Cogeneration      Wind  Fuel-Gas    Coal  \
# datetime_utc
# 2015-01-01 00:00:00+01:00        1586.9  5517.400     421.6  5077.9
# 2015-01-01 01:00:00+01:00        1591.2  5034.400     422.3  5086.3
# ...                                 ...       ...       ...     ...
# 2022-12-31 22:00:00+01:00         760.6  8871.225       NaN   260.0
# 2022-12-31 23:00:00+01:00         761.6  7506.300       NaN   260.0
#
#                            Balearic Link  Pumping Consumption  Solar Thermal  \
# datetime_utc
# 2015-01-01 00:00:00+01:00         -128.0             -850.000           16.0
# 2015-01-01 01:00:00+01:00         -102.0             -850.000           16.0
# ...                                  ...                  ...            ...
# 2022-12-31 22:00:00+01:00         -153.0            -1846.700            NaN
# 2022-12-31 23:00:00+01:00         -128.0            -2632.025            NaN
#
#                            Solar Photovoltaic  Combined Cycle  \
# datetime_utc
# 2015-01-01 00:00:00+01:00                 NaN         3458.10
# 2015-01-01 01:00:00+01:00                 NaN         3789.50
# ...                                       ...             ...
# 2022-12-31 22:00:00+01:00                 1.7         1725.00
# 2022-12-31 23:00:00+01:00                 1.6         2104.55
#
#                            Pumping Turbine  Nuclear
# datetime_utc
# 2015-01-01 00:00:00+01:00              NaN  7105.00
# 2015-01-01 01:00:00+01:00              NaN  7104.00
# ...                                    ...      ...
# 2022-12-31 22:00:00+01:00         689.6000  6457.75
# 2022-12-31 23:00:00+01:00         240.9125  6415.45
#
# [70128 rows x 19 columns]

# %% [markdown]
# ## Temporal columns

# %% [markdown]
# ### Create

# %%
s = df_base.index

# %%
df_time = pd.DataFrame({
    'year': s.year,
    'month': s.month,
    'day': s.day,
    'hour': s.hour,
    'weekday': s.weekday,
}, index=s)

df_time['weekend'] = (df_time['weekday'] >= 5).astype(int)
df_time
# Out:
#                            year  month  day  hour  weekday  weekend
# datetime_utc
# 2015-01-01 00:00:00+01:00  2015      1    1     0        3        0
# 2015-01-01 01:00:00+01:00  2015      1    1     1        3        0
# ...                         ...    ...  ...   ...      ...      ...
# 2022-12-31 22:00:00+01:00  2022     12   31    22        5        1
# 2022-12-31 23:00:00+01:00  2022     12   31    23        5        1
#
# [70128 rows x 6 columns]

# %% [markdown]
# ### Concatenate `DataFrames`

# %%
df = pd.concat([df_time, df_base], axis=1)
df
# Out:
#                            year  month  day  hour  weekday  weekend  \
# datetime_utc
# 2015-01-01 00:00:00+01:00  2015      1    1     0        3        0
# 2015-01-01 01:00:00+01:00  2015      1    1     1        3        0
# ...                         ...    ...  ...   ...      ...      ...
# 2022-12-31 22:00:00+01:00  2022     12   31    22        5        1
# 2022-12-31 23:00:00+01:00  2022     12   31    23        5        1
#
#                            Hydraulic  Adjustment P48  Balance Andorra  \
# datetime_utc
# 2015-01-01 00:00:00+01:00    2621.90          1300.0            -36.0
# 2015-01-01 01:00:00+01:00    2532.30          1000.0            -35.0
# ...                              ...             ...              ...
# 2022-12-31 22:00:00+01:00    4055.50          -200.0            -67.0
# 2022-12-31 23:00:00+01:00    3963.95          -200.0            -62.0
#
#                            Balance Morocco  ...      Wind  Fuel-Gas    Coal  \
# datetime_utc                                ...
# 2015-01-01 00:00:00+01:00           -540.0  ...  5517.400     421.6  5077.9
# 2015-01-01 01:00:00+01:00           -600.0  ...  5034.400     422.3  5086.3
# ...                                    ...  ...       ...       ...     ...
# 2022-12-31 22:00:00+01:00           -740.0  ...  8871.225       NaN   260.0
# 2022-12-31 23:00:00+01:00           -750.0  ...  7506.300       NaN   260.0
#
#                            Balearic Link  Pumping Consumption  Solar Thermal  \
# datetime_utc
# 2015-01-01 00:00:00+01:00         -128.0             -850.000           16.0
# 2015-01-01 01:00:00+01:00         -102.0             -850.000           16.0
# ...                                  ...                  ...            ...
# 2022-12-31 22:00:00+01:00         -153.0            -1846.700            NaN
# 2022-12-31 23:00:00+01:00         -128.0            -2632.025            NaN
#
#                            Solar Photovoltaic  Combined Cycle  \
# datetime_utc
# 2015-01-01 00:00:00+01:00                 NaN         3458.10
# 2015-01-01 01:00:00+01:00                 NaN         3789.50
# ...                                       ...             ...
# 2022-12-31 22:00:00+01:00                 1.7         1725.00
# 2022-12-31 23:00:00+01:00                 1.6         2104.55
#
#                            Pumping Turbine  Nuclear
# datetime_utc
# 2015-01-01 00:00:00+01:00              NaN  7105.00
# 2015-01-01 01:00:00+01:00              NaN  7104.00
# ...                                    ...      ...
# 2022-12-31 22:00:00+01:00         689.6000  6457.75
# 2022-12-31 23:00:00+01:00         240.9125  6415.45
#
# [70128 rows x 25 columns]

# %% [markdown]
# ### Set temporal columns as `index`

# %%
df = df.set_index(['year', 'month', 'day', 'hour', 'weekday', 'weekend'])
df
# Out:
#                                      Hydraulic  Adjustment P48  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0          2621.90          1300.0
#                1    3       0          2532.30          1000.0
# ...                                        ...             ...
# 2022 12    31  22   5       1          4055.50          -200.0
#                23   5       1          3963.95          -200.0
#
#                                      Balance Andorra  Balance Morocco  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0                  -36.0           -540.0
#                1    3       0                  -35.0           -600.0
# ...                                              ...              ...
# 2022 12    31  22   5       1                  -67.0           -740.0
#                23   5       1                  -62.0           -750.0
#
#                                      Balance France  Balance Portugal  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0               -1000.0             291.7
#                1    3       0               -1100.0             -44.1
# ...                                             ...               ...
# 2022 12    31  22   5       1               -1715.8            3355.0
#                23   5       1                -258.0            2755.0
#
#                                      Other Renewables  Non-Renewable Waste  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0                   486.4                  NaN
#                1    3       0                   486.4                  NaN
# ...                                               ...                  ...
# 2022 12    31  22   5       1                   259.2                264.7
#                23   5       1                   257.2                264.9
#
#                                      Cogeneration      Wind  Fuel-Gas    Coal  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0              1586.9  5517.400     421.6  5077.9
#                1    3       0              1591.2  5034.400     422.3  5086.3
# ...                                           ...       ...       ...     ...
# 2022 12    31  22   5       1               760.6  8871.225       NaN   260.0
#                23   5       1               761.6  7506.300       NaN   260.0
#
#                                      Balearic Link  Pumping Consumption  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0               -128.0             -850.000
#                1    3       0               -102.0             -850.000
# ...                                            ...                  ...
# 2022 12    31  22   5       1               -153.0            -1846.700
#                23   5       1               -128.0            -2632.025
#
#                                      Solar Thermal  Solar Photovoltaic  \
# year month day hour weekday weekend
# 2015 1     1   0    3       0                 16.0                 NaN
#                1    3       0                 16.0                 NaN
# ...                                            ...                 ...
# 2022 12    31  22   5       1                  NaN                 1.7
#                23   5       1                  NaN                 1.6
#
#                                      Combined Cycle  Pumping Turbine  Nuclear
# year month day hour weekday weekend
# 2015 1     1   0    3       0               3458.10              NaN  7105.00
#                1    3       0               3789.50              NaN  7104.00
# ...                                             ...              ...      ...
# 2022 12    31  22   5       1               1725.00         689.6000  6457.75
#                23   5       1               2104.55         240.9125  6415.45
#
# [70128 rows x 19 columns]

# %% [markdown]
# ## Export to `parquet`

# %%
df.to_parquet('../data/p48_2015_2022_EN.parquet')
